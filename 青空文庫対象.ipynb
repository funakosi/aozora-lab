# %% [markdown]
# # 青空文庫の分析対象

# %% [markdown]
# - 日本文学（分類番号：NDC 913含む）
# - 文字遣い種別：新字新仮名
# - 作品著作権：なし

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## データ取得

# %% [markdown]
# [「公開中　作家リスト：全て」のページ](https://www.aozora.gr.jp/index_pages/person_all.html)」で共有されているリストを取得
#
# https://www.aozora.gr.jp/index_pages/list_person_all_extended_utf8.zip

# %%
# !wget https://www.aozora.gr.jp/index_pages/list_person_all_extended_utf8.zip
# Out:
# --2023-05-23 00:04:34--  https://www.aozora.gr.jp/index_pages/list_person_all_extended_utf8.zip
# Resolving www.aozora.gr.jp (www.aozora.gr.jp)... 59.106.13.115
# Connecting to www.aozora.gr.jp (www.aozora.gr.jp)|59.106.13.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2001614 (1.9M) [application/zip]
# Saving to: ‘list_person_all_extended_utf8.zip.1’
#
# list_person_all_ext 100%[===================>]   1.91M  8.44MB/s    in 0.2s
#
# 2023-05-23 00:04:35 (8.44 MB/s) - ‘list_person_all_extended_utf8.zip.1’ saved [2001614/2001614]

# %% [markdown]
# ダウンロードしたZIPファイルを解凍する．

# %%
# !unzip list_person_all_extended_utf8.zip
# Out:
# Archive:  list_person_all_extended_utf8.zip
# replace list_person_all_extended_utf8.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# pandasで読み取る
df_all = pd.read_csv('list_person_all_extended_utf8.csv')
df_all.head()
# Out:
#     作品ID          作品名         作品名読み        ソート用読み   副題 副題読み   原題   初出  \
# 0  59898  ウェストミンスター寺院  ウェストミンスターじいん  うえすとみんすたあしいん  NaN  NaN  NaN  NaN
# 1  56078         駅伝馬車       えきでんばしゃ       えきてんはしや  NaN  NaN  NaN  NaN
# 2  60224          駅馬車         えきばしゃ         えきはしや  NaN  NaN  NaN  NaN
# 3  60225       寡婦とその子        かふとそのこ        かふとそのこ  NaN  NaN  NaN  NaN
# 4  60231        クリスマス         クリスマス         くりすます  NaN  NaN  NaN  NaN
#
#       分類番号 文字遣い種別  ...                                        テキストファイルURL  \
# 0  NDC 933  新字新仮名  ...  https://www.aozora.gr.jp/cards/001257/files/59...
# 1  NDC 933  旧字旧仮名  ...  https://www.aozora.gr.jp/cards/001257/files/56...
# 2  NDC 933  新字新仮名  ...  https://www.aozora.gr.jp/cards/001257/files/60...
# 3  NDC 933  新字新仮名  ...  https://www.aozora.gr.jp/cards/001257/files/60...
# 4  NDC 933  新字新仮名  ...  https://www.aozora.gr.jp/cards/001257/files/60...
#
#   テキストファイル最終更新日 テキストファイル符号化方式 テキストファイル文字集合  テキストファイル修正回数  \
# 0    2020-03-28      ShiftJIS   JIS X 0208           0.0
# 1    2013-09-03      ShiftJIS   JIS X 0208           0.0
# 2    2021-04-27      ShiftJIS   JIS X 0208           0.0
# 3    2021-09-27      ShiftJIS   JIS X 0208           0.0
# 4    2021-11-27      ShiftJIS   JIS X 0208           0.0
#
#                                    XHTML/HTMLファイルURL XHTML/HTMLファイル最終更新日  \
# 0  https://www.aozora.gr.jp/cards/001257/files/59...          2020-03-28
# 1  https://www.aozora.gr.jp/cards/001257/files/56...          2013-09-03
# 2  https://www.aozora.gr.jp/cards/001257/files/60...          2021-04-27
# 3  https://www.aozora.gr.jp/cards/001257/files/60...          2021-09-27
# 4  https://www.aozora.gr.jp/cards/001257/files/60...          2021-11-27
#
#   XHTML/HTMLファイル符号化方式 XHTML/HTMLファイル文字集合 XHTML/HTMLファイル修正回数
# 0            ShiftJIS         JIS X 0208                0.0
# 1            ShiftJIS         JIS X 0208                0.0
# 2            ShiftJIS         JIS X 0208                0.0
# 3            ShiftJIS         JIS X 0208                0.0
# 4            ShiftJIS         JIS X 0208                0.0
#
# [5 rows x 55 columns]

# %%
# 作品数確認
df_all.shape
# Out:
# (18798, 55)

# %%
# 列名作成 -> 最後に必要なもののみ残す
df_all.columns
# Out:
# Index(['作品ID', '作品名', '作品名読み', 'ソート用読み', '副題', '副題読み', '原題', '初出', '分類番号',
#        '文字遣い種別', '作品著作権フラグ', '公開日', '最終更新日', '図書カードURL', '人物ID', '姓', '名',
#        '姓読み', '名読み', '姓読みソート用', '名読みソート用', '姓ローマ字', '名ローマ字', '役割フラグ', '生年月日',
#        '没年月日', '人物著作権フラグ', '底本名1', '底本出版社名1', '底本初版発行年1', '入力に使用した版1',
#        '校正に使用した版1', '底本の親本名1', '底本の親本出版社名1', '底本の親本初版発行年1', '底本名2', '底本出版社名2',
#        '底本初版発行年2', '入力に使用した版2', '校正に使用した版2', '底本の親本名2', '底本の親本出版社名2',
#        '底本の親本初版発行年2', '入力者', '校正者', 'テキストファイルURL', 'テキストファイル最終更新日',
#        'テキストファイル符号化方式', 'テキストファイル文字集合', 'テキストファイル修正回数', 'XHTML/HTMLファイルURL',
#        'XHTML/HTMLファイル最終更新日', 'XHTML/HTMLファイル符号化方式', 'XHTML/HTMLファイル文字集合',
#        'XHTML/HTMLファイル修正回数'],
#       dtype='object')

# %% [markdown]
# ## 絞り込み

# %%
# 日本文学のみ
df_jp = df_all[df_all['分類番号'].str.contains('NDC 913', na=False)]
df_jp.shape
# Out:
# (5181, 55)

# %%
# 翻訳者は除外
df_jp = df_jp[df_jp['役割フラグ']=='著者']
df_jp.shape
# Out:
# (5111, 55)

# %%
# 新カナのみを対象とする
df_jp_new = df_jp[df_jp['文字遣い種別']=='新字新仮名']
df_jp_new.shape
# Out:
# (3576, 55)

# %%
# 作品著作権切れ
df_jp_new_free = df_jp_new[df_jp_new['作品著作権フラグ']=='なし']
df_jp_new_free.shape
# Out:
# (3507, 55)

# %%
# 作者著作権切れ
df_jp_new_free = df_jp_new_free[df_jp_new_free['人物著作権フラグ']=='なし']
df_jp_new_free.shape
# Out:
# (3507, 55)

# %%
# 作者名が空白は除外
df_jp_new_free_name = df_jp_new_free[~ df_jp_new_free.loc[:,'名'].isnull()]
df_jp_new_free_name.shape
# Out:
# (3442, 55)

# %%
# ここまでの結果を別変数にコピー
df_target = df_jp_new_free_name.copy()
df_target.shape
# Out:
# (3442, 55)

# %% [markdown]
# ## 列の絞り込み

# %% [markdown]
# ### 氏名，かな

# %%
df_kanji = df_target['姓'] + ' ' + df_target['名']
df_kana = df_target['姓読み'] + ' ' + df_target['名読み']

# %%
df_name = pd.concat([df_target['人物ID'], df_kanji, df_kana], axis=1).rename(columns={0: '氏名', 1: '読み'})
df_name.head()
# Out:
#     人物ID      氏名            読み
# 33   374   饗庭 篁村      あえば こうそん
# 68   879  芥川 竜之介  あくたがわ りゅうのすけ
# 71   879  芥川 竜之介  あくたがわ りゅうのすけ
# 72   879  芥川 竜之介  あくたがわ りゅうのすけ
# 79   879  芥川 竜之介  あくたがわ りゅうのすけ

# %% [markdown]
# ### 作品名

# %%
df_work = df_target.loc[:, ['作品ID', '作品名', '副題', '作品名読み']]
df_work.head()
# Out:
#      作品ID       作品名   副題          作品名読み
# 33  45754        良夜  NaN           りょうや
# 68     73     或敵打の話  NaN    あるかたきうちのはなし
# 71    122  或日の大石内蔵助  NaN  あるひのおおいしくらのすけ
# 72    129     或恋愛小説  NaN    あるれんあいしょうせつ
# 79     57       一夕話  NaN          いっせきわ

# %% [markdown]
# ### URL

# %%
df_url = df_target.loc[:, ['図書カードURL', 'テキストファイルURL']]
df_url.head()
# Out:
#                                              図書カードURL  \
# 33  https://www.aozora.gr.jp/cards/000374/card4575...
# 68  https://www.aozora.gr.jp/cards/000879/card73.html
# 71  https://www.aozora.gr.jp/cards/000879/card122....
# 72  https://www.aozora.gr.jp/cards/000879/card129....
# 79  https://www.aozora.gr.jp/cards/000879/card57.html
#
#                                           テキストファイルURL
# 33  https://www.aozora.gr.jp/cards/000374/files/45...
# 68  https://www.aozora.gr.jp/cards/000879/files/73...
# 71  https://www.aozora.gr.jp/cards/000879/files/12...
# 72  https://www.aozora.gr.jp/cards/000879/files/12...
# 79  https://www.aozora.gr.jp/cards/000879/files/57...

# %% [markdown]
# ### 結合

# %% [markdown]
# 名前，作品，URLを結合する

# %%
df = pd.concat([df_name, df_work, df_url], axis=1)
df = df.reset_index().drop(['index'], axis=1) # index振り直し
df.head()
# Out:
#    人物ID      氏名            読み   作品ID       作品名   副題          作品名読み  \
# 0   374   饗庭 篁村      あえば こうそん  45754        良夜  NaN           りょうや
# 1   879  芥川 竜之介  あくたがわ りゅうのすけ     73     或敵打の話  NaN    あるかたきうちのはなし
# 2   879  芥川 竜之介  あくたがわ りゅうのすけ    122  或日の大石内蔵助  NaN  あるひのおおいしくらのすけ
# 3   879  芥川 竜之介  あくたがわ りゅうのすけ    129     或恋愛小説  NaN    あるれんあいしょうせつ
# 4   879  芥川 竜之介  あくたがわ りゅうのすけ     57       一夕話  NaN          いっせきわ
#
#                                             図書カードURL  \
# 0  https://www.aozora.gr.jp/cards/000374/card4575...
# 1  https://www.aozora.gr.jp/cards/000879/card73.html
# 2  https://www.aozora.gr.jp/cards/000879/card122....
# 3  https://www.aozora.gr.jp/cards/000879/card129....
# 4  https://www.aozora.gr.jp/cards/000879/card57.html
#
#                                          テキストファイルURL
# 0  https://www.aozora.gr.jp/cards/000374/files/45...
# 1  https://www.aozora.gr.jp/cards/000879/files/73...
# 2  https://www.aozora.gr.jp/cards/000879/files/12...
# 3  https://www.aozora.gr.jp/cards/000879/files/12...
# 4  https://www.aozora.gr.jp/cards/000879/files/57...

# %%
df.insert(0, '対象', True) # 対象列の追加
df['テキストファイルパス'] = '' # 保存場所
df['備考'] = ''

# %%
df.head()
# Out:
#      対象  人物ID      氏名            読み   作品ID       作品名   副題          作品名読み  \
# 0  True   374   饗庭 篁村      あえば こうそん  45754        良夜  NaN           りょうや
# 1  True   879  芥川 竜之介  あくたがわ りゅうのすけ     73     或敵打の話  NaN    あるかたきうちのはなし
# 2  True   879  芥川 竜之介  あくたがわ りゅうのすけ    122  或日の大石内蔵助  NaN  あるひのおおいしくらのすけ
# 3  True   879  芥川 竜之介  あくたがわ りゅうのすけ    129     或恋愛小説  NaN    あるれんあいしょうせつ
# 4  True   879  芥川 竜之介  あくたがわ りゅうのすけ     57       一夕話  NaN          いっせきわ
#
#                                             図書カードURL  \
# 0  https://www.aozora.gr.jp/cards/000374/card4575...
# 1  https://www.aozora.gr.jp/cards/000879/card73.html
# 2  https://www.aozora.gr.jp/cards/000879/card122....
# 3  https://www.aozora.gr.jp/cards/000879/card129....
# 4  https://www.aozora.gr.jp/cards/000879/card57.html
#
#                                          テキストファイルURL テキストファイルパス 備考
# 0  https://www.aozora.gr.jp/cards/000374/files/45...
# 1  https://www.aozora.gr.jp/cards/000879/files/73...
# 2  https://www.aozora.gr.jp/cards/000879/files/12...
# 3  https://www.aozora.gr.jp/cards/000879/files/12...
# 4  https://www.aozora.gr.jp/cards/000879/files/57...

# %%
df.shape
# Out:
# (3442, 12)

# %%
# csvに出力
df.to_csv('target.csv', index=False)

# %%
# 行単位で扱う場合は以下
for i, d in df.iterrows():
    print(f'idx: {i}')
    print('--------')
    print(d)
    break
# Out:
# idx: 0
# --------
# 対象                                                          True
# 人物ID                                                         374
# 氏名                                                         饗庭 篁村
# 読み                                                      あえば こうそん
# 作品ID                                                       45754
# 作品名                                                           良夜
# 副題                                                           NaN
# 作品名読み                                                       りょうや
# 図書カードURL       https://www.aozora.gr.jp/cards/000374/card4575...
# テキストファイルURL    https://www.aozora.gr.jp/cards/000374/files/45...
# テキストファイルパス
# 備考
# Name: 0, dtype: object

# %% [markdown]
# ## データ読み込み例

# %%
sample = df.loc[0]['テキストファイルURL']
sample
# Out:
# 'https://www.aozora.gr.jp/cards/000374/files/45754_ruby_23695.zip'

# %%
pd.read_csv(sample, encoding='cp932', names=['text'])
# Out:
#                                                  text
# 0                                                  良夜
# 1                                                饗庭篁村
# 2   ----------------------------------------------...
# 3                                   【テキスト中に現れる記号について】
# 4                                               《》：ルビ
# 5                                         （例）手習《てならい》
# 6                               ｜：ルビの付く文字列の始まりを特定する記号
# 7                                     （例）末｜覚束《おぼつか》なき
# 8                          ［＃］：入力者注　主に外字の説明や、傍点の位置の指定
# 9              　　　（数字は、JIS X 0213の面区点番号、または底本のページと行数）
# 10                   （例）※［＃「足へん＋宛」、第3水準1-92-36］《もが》くを
# 11  ----------------------------------------------...
# 12  　予は越後三条の生れなり。父は農と商を兼ねたり。伯父は春庵とて医師なり。余は父よりは伯父に愛...
# 13  　穂垂の息子が東京へエライ者になりに行くぞ目出とう送りてやれよとて、親族よりの餞別見送り、父...
# 14  　翌朝騒がしくまた慌ただしく催されて馬車に乗る。乗ればなかなか馬車は出ず。やがて九時にもなら...
# 15  　足だまりの城として伯父より添書《そえがき》ありしは、浅草三間町の深沢某なり。この人元よりの...
# 16  　浅草諏訪町の河岸にて木造の外だけを飾りに煉瓦《れんが》に積みしなれば、暗くして湿りたり。こ...
# 17  　月日の経つは活字を拾うより速かに、器械の廻るより早し。その年の夏となりしが四五月頃の気候の...
# 18  　懐しき父母の許より手紙届きたり。それは西風｜槭樹《せきじゅ》を揺がすの候にして、予はまずそ...
# 19  　予は深沢にもその事を話し、届きたる袷に着替え、伯父よりの添書を持て下谷西町のその人を尋ねた...
# 20  　先に茶を運びし小女は、予が先夜吾妻橋にて死をとどめたる女なりし。主公は予をまた車夫に命じて...
# 21  　予はこれまでにて筆を措《お》くべし。これよりして悦び悲しみ大憂愁大歓喜の事は老後を待ちて記...
# 22                          底本：「新潟県文学全集　第1巻　明治編」郷土出版社
# 23                              　　　1995（平成7）年10月26日発行
# 24                               底本の親本：「明治文学全集26」筑摩書房
# 25                                   　　　1981（昭和56）年4月
# 26    ※底本は、物を数える際や地名などに用いる「ヶ」（区点番号5-86）を、大振りにつくっています。
# 27                              入力：高田農業高校生産技術科流通経済コース
# 28                                            校正：小林繁雄
# 29                                       2006年7月28日作成
# 30                                        青空文庫作成ファイル：
# 31  このファイルは、インターネットの図書館、青空文庫（http://www.aozora.gr....
