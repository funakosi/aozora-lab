# %% [markdown]
# # 青空文庫データクレンジング

# %%
import os
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## データ取得

# %% [markdown]
# - 以降は，Google Colaboで実行されることを想定しています．
# - 参考：[Pythonで青空文庫データを自然言語処理向けにさくっと一括テキスト整形＋前処理](https://qiita.com/dzbt_dzbt/items/593dbd698a07c12a771c)

# %%
folder_name = 'aozora'

# %%
# !cd /content
# !rm -rf aozora # 必要に応じて削除
# !mkdir aozora #フォルダ作成
# %cd aozora
# Out:
# /content/aozora

# %% [markdown]
# - データ量が多いので，夏目漱石のテキストだけを取得するように設定
# - これまでのコミット履歴は不要なので，最新のものだけ取得している(--depth=1)
#   - 参考：[【GitHub記録】特定のディレクトリのみcloneする方法](https://itosae.com/github_sparsechekout/)

# %%
# !git init
# !git remote add origin https://github.com/aozorabunko/aozorabunko.git
# !git config core.sparsecheckout true
# !echo 'cards/000148/' > .git/info/sparse-checkout # 000148:夏目漱石
# !git pull --depth=1 origin master
# Out:
# Initialized empty Git repository in /content/aozora/.git/
# remote: Enumerating objects: 74477, done.
# remote: Counting objects: 100% (74477/74477), done.
# remote: Compressing objects: 100% (60121/60121), done.
# remote: Total 74477 (delta 24900), reused 53950 (delta 14169), pack-reused 0
# Receiving objects: 100% (74477/74477), 2.25 GiB | 31.09 MiB/s, done.
# Resolving deltas: 100% (24900/24900), done.
# From https://github.com/aozorabunko/aozorabunko
#  * branch                master     -> FETCH_HEAD
#  * [new branch]          master     -> origin/master

# %% [markdown]
# カレントフォルダを元にもとしておく．
# - 参考:https://qiita.com/bear_montblanc/items/64d7efd9e4ea7caa98f9

# %%
# カレントフォルダを元に戻しておく
# %cd /content/
# !ls
# Out:
# /content
# aozora	sample_data

# %% [markdown]
# ## 関数定義

# %%
author_id = '000148'  # 青空文庫の作家番号
author_name = '夏目漱石'  # 青空文庫の表記での作家名

write_title = False # 2カラム目に作品名を入れるか
write_header = True # 1行目をカラム名にするか（カラム名「text」「title」）
save_utf8_org = True  # 元データをUTF-8にしたテキストファイルを保存するか
split_kuten = True # 句点「。」で分割するか

out_dir = Path(f'/content/aozora/cards/{author_id}/files/')  # ファイル出力先
tx_org_dir = Path(out_dir / './org/')  # 元テキストのUTF-8変換ファイルの保存先
tx_edit_dir = Path(out_dir / './edit/')  # テキスト整形後のファイル保存先

# %%
def text_cleanse_df(df):
    # 本文の先頭を探す（'---…'区切りの直後から本文が始まる前提）
    head_tx = list(df[df['text'].str.contains(
        '-------------------------------------------------------')].index)
    # 本文の末尾を探す（'底本：'の直前に本文が終わる前提）
    atx = list(df[df['text'].str.contains('底本：')].index)
    if head_tx == []:
        # もし'---…'区切りが無い場合は、作家名の直後に本文が始まる前提
        head_tx = list(df[df['text'].str.contains(author_name)].index)
        head_tx_num = head_tx[0]+1
    else:
        # 2個目の'---…'区切り直後から本文が始まる
        head_tx_num = head_tx[1]+1
    df_e = df[head_tx_num:atx[0]]

    # 句点で分割
    if split_kuten:
        # df.assign(コメント=df['コメント'].str.split(r'(?<=。)(?=..)')).explode('コメント')
        df_e = df_e.assign(text=df['text'].str.split(r'(?<=。)(?=..)')).explode('text')

    # 青空文庫の書式削除
    df_e = df_e.replace({'text': {'《.*?》': ''}}, regex=True)
    df_e = df_e.replace({'text': {'［.*?］': ''}}, regex=True)
    df_e = df_e.replace({'text': {'｜': ''}}, regex=True)

    # 字下げ（行頭の全角スペース）を削除
    df_e = df_e.replace({'text': {'　': ''}}, regex=True)

    # 節区切りを削除
    df_e = df_e.replace({'text': {'^.$': ''}}, regex=True)
    df_e = df_e.replace({'text': {'^―――.*$': ''}}, regex=True)
    df_e = df_e.replace({'text': {'^＊＊＊.*$': ''}}, regex=True)
    df_e = df_e.replace({'text': {'^×××.*$': ''}}, regex=True)

    # 記号、および記号削除によって残ったカッコを削除
    # df_e = df_e.replace({'text': {'―': ''}}, regex=True)
    # df_e = df_e.replace({'text': {'…': ''}}, regex=True)
    # df_e = df_e.replace({'text': {'※': ''}}, regex=True)
    df_e = df_e.replace({'text': {'「」': ''}}, regex=True)

    # 一文字以下で構成されている行を削除
    df_e['length'] = df_e['text'].map(lambda x: len(x))
    df_e = df_e[df_e['length'] > 1]

    # インデックスがずれるので振りなおす
    df_e = df_e.reset_index().drop(['index'], axis=1)

    # 空白行を削除する（念のため）
    df_e = df_e[~(df_e['text'] == '')]

    # インデックスがずれるので振り直し、文字の長さの列を削除する
    df_e = df_e.reset_index().drop(['index', 'length'], axis=1)
    return df_e

# %%
def save_cleanse_text(target_file):
    try:
        # ファイルの読み込み
        print(target_file)
        # Pandas DataFrameとして読み込む（cp932で読み込まないと異体字が読めない）
        df_tmp = pd.read_csv(target_file, encoding='cp932', names=['text'])
        # 元データをUTF-8に変換してテキストファイルを保存
        if save_utf8_org:
            out_org_file_nm = Path(target_file.stem + '_org_utf-8.tsv')
            df_tmp.to_csv(Path(tx_org_dir / out_org_file_nm), sep='\t',
                          encoding='utf-8', index=None)
        # テキスト整形
        df_tmp_e = text_cleanse_df(df_tmp)
        if write_title:
            # タイトル列を作る
            df_tmp_e['title'] = df_tmp['text'][0]
        out_edit_file_nm = Path(target_file.stem + '_clns_utf-8.txt')
        df_tmp_e.to_csv(Path(tx_edit_dir / out_edit_file_nm), sep='\t',
                        encoding='utf-8', index=None, header=write_header)
    except:
        print(f'ERROR: {target_file}')

# %%
def main():
    # zipファイルのリストを作成
    zip_list = list(out_dir.glob('*.zip'))
    # 保存ディレクトリを作成しておく
    tx_edit_dir.mkdir(exist_ok=True, parents=True)
    if save_utf8_org:
        tx_org_dir.mkdir(exist_ok=True, parents=True)

    for target_file in zip_list:
        save_cleanse_text(target_file)

# %% [markdown]
# ## データ取得＆クレンジング実行

# %%
main()
# Out:
# /content/aozora/cards/000148/files/4681_ruby_9461.zip
# /content/aozora/cards/000148/files/2671_ruby_6335.zip
# /content/aozora/cards/000148/files/1746_ruby_18324.zip
# /content/aozora/cards/000148/files/59017_ruby_70128.zip
# /content/aozora/cards/000148/files/755_ruby_3617.zip
# ERROR: /content/aozora/cards/000148/files/755_ruby_3617.zip
# /content/aozora/cards/000148/files/753_ruby_1701.zip
# /content/aozora/cards/000148/files/1104_ruby_4554.zip
# /content/aozora/cards/000148/files/1749_ruby_19433.zip
# /content/aozora/cards/000148/files/779_ruby_2743.zip
# ERROR: /content/aozora/cards/000148/files/779_ruby_2743.zip
# /content/aozora/cards/000148/files/58277_ruby_69902.zip
# /content/aozora/cards/000148/files/4683_ruby_9475.zip
# /content/aozora/cards/000148/files/770_ruby.zip
# ERROR: /content/aozora/cards/000148/files/770_ruby.zip
# /content/aozora/cards/000148/files/780_ruby_569.zip
# /content/aozora/cards/000148/files/1076_ruby_4527.zip
# ERROR: /content/aozora/cards/000148/files/1076_ruby_4527.zip
# /content/aozora/cards/000148/files/4672_ruby_8553.zip
# /content/aozora/cards/000148/files/797_ruby.zip
# /content/aozora/cards/000148/files/58842_ruby_76723.zip
# ERROR: /content/aozora/cards/000148/files/58842_ruby_76723.zip
# /content/aozora/cards/000148/files/795_ruby.zip
# /content/aozora/cards/000148/files/2376_ruby_2303.zip
# /content/aozora/cards/000148/files/770_txt.zip
# ERROR: /content/aozora/cards/000148/files/770_txt.zip
# /content/aozora/cards/000148/files/58276_ruby_63197.zip
# /content/aozora/cards/000148/files/1751_ruby_6331.zip
# /content/aozora/cards/000148/files/4684_ruby_9469.zip
# /content/aozora/cards/000148/files/1046_ruby_4521.zip
# /content/aozora/cards/000148/files/2670_ruby_6329.zip
# /content/aozora/cards/000148/files/788_ruby.zip
# /content/aozora/cards/000148/files/770_ruby_1713.zip
# ERROR: /content/aozora/cards/000148/files/770_ruby_1713.zip
# /content/aozora/cards/000148/files/2679_ruby_6325.zip
# /content/aozora/cards/000148/files/47148_ruby_32216.zip
# /content/aozora/cards/000148/files/759_ruby_3240.zip
# /content/aozora/cards/000148/files/56923_ruby_66668.zip
# /content/aozora/cards/000148/files/2667_ruby_6347.zip
# /content/aozora/cards/000148/files/789_ruby_5639.zip
# /content/aozora/cards/000148/files/764_txt.zip
# /content/aozora/cards/000148/files/56143_ruby_50824.zip
# /content/aozora/cards/000148/files/775_ruby_2064.zip
# ERROR: /content/aozora/cards/000148/files/775_ruby_2064.zip
# /content/aozora/cards/000148/files/775_txt.zip
# ERROR: /content/aozora/cards/000148/files/775_txt.zip
# /content/aozora/cards/000148/files/763_txt.zip
# /content/aozora/cards/000148/files/799_ruby_6024.zip
# /content/aozora/cards/000148/files/794_ruby_4237.zip
# ERROR: /content/aozora/cards/000148/files/794_ruby_4237.zip
# /content/aozora/cards/000148/files/56900_ruby_53913.zip
# /content/aozora/cards/000148/files/2315_ruby_2410.zip
# /content/aozora/cards/000148/files/764_ruby_2927.zip
# /content/aozora/cards/000148/files/798_ruby_2413.zip
# /content/aozora/cards/000148/files/2371_ruby_2071.zip
# /content/aozora/cards/000148/files/773_ruby_5968.zip
# /content/aozora/cards/000148/files/768_ruby_2686.zip
# /content/aozora/cards/000148/files/42297_txt_14025.zip
# /content/aozora/cards/000148/files/2313_ruby_2287.zip
# /content/aozora/cards/000148/files/778_ruby_2283.zip
# /content/aozora/cards/000148/files/799_txt.zip
# /content/aozora/cards/000148/files/2677_ruby_6351.zip
# /content/aozora/cards/000148/files/782_ruby_2315.zip
# /content/aozora/cards/000148/files/767_ruby_3256.zip
# /content/aozora/cards/000148/files/751_ruby_1539.zip
# /content/aozora/cards/000148/files/795_ruby_1725.zip
# /content/aozora/cards/000148/files/788_txt.zip
# /content/aozora/cards/000148/files/797_ruby_1729.zip
# /content/aozora/cards/000148/files/788_ruby_2857.zip
# /content/aozora/cards/000148/files/769_ttz.zip
# ERROR: /content/aozora/cards/000148/files/769_ttz.zip
# /content/aozora/cards/000148/files/781_ruby_2101.zip
# /content/aozora/cards/000148/files/2370_ruby_2080.zip
# /content/aozora/cards/000148/files/2671_ruby.zip
# /content/aozora/cards/000148/files/2680_ruby_6345.zip
# /content/aozora/cards/000148/files/4687_ruby_9467.zip
# /content/aozora/cards/000148/files/1750_ruby_19434.zip
# /content/aozora/cards/000148/files/1073_ruby_4526.zip
# /content/aozora/cards/000148/files/798_ruby.zip
# /content/aozora/cards/000148/files/2668_ruby_6349.zip
# /content/aozora/cards/000148/files/783_ruby_1311.zip
# /content/aozora/cards/000148/files/2373_ruby_2077.zip
# /content/aozora/cards/000148/files/762_ruby_1705.zip
# /content/aozora/cards/000148/files/757_ruby_2986.zip
# /content/aozora/cards/000148/files/50478_ruby_40733.zip
# /content/aozora/cards/000148/files/797_txt.zip
# /content/aozora/cards/000148/files/791_ruby_1549.zip
# /content/aozora/cards/000148/files/758_ruby_6056.zip
# /content/aozora/cards/000148/files/796_ruby.zip
# /content/aozora/cards/000148/files/58278_txt_69684.zip
# /content/aozora/cards/000148/files/769_ruby_565.zip
# /content/aozora/cards/000148/files/4682_ruby_9463.zip
# /content/aozora/cards/000148/files/4686_ruby_9477.zip
# /content/aozora/cards/000148/files/784_ruby_1721.zip
# /content/aozora/cards/000148/files/2674_ruby_6327.zip
# /content/aozora/cards/000148/files/2676_ruby_6343.zip
# /content/aozora/cards/000148/files/763_ruby_1709.zip
# /content/aozora/cards/000148/files/774_ruby_1640.zip
# /content/aozora/cards/000148/files/763_ruby.zip
# /content/aozora/cards/000148/files/1747_ruby_5349.zip
# /content/aozora/cards/000148/files/784_txt.zip
# /content/aozora/cards/000148/files/793_ruby_2448.zip
# /content/aozora/cards/000148/files/42156_ruby_16023.zip
# /content/aozora/cards/000148/files/2314_ruby_2291.zip
# /content/aozora/cards/000148/files/4685_ruby_9479.zip
# /content/aozora/cards/000148/files/2669_ruby_6341.zip
# /content/aozora/cards/000148/files/766_ruby_2068.zip
# /content/aozora/cards/000148/files/759_txt.zip
# /content/aozora/cards/000148/files/764_ruby.zip
# /content/aozora/cards/000148/files/787_ruby_2295.zip
# /content/aozora/cards/000148/files/776_ruby_6020.zip
# ERROR: /content/aozora/cards/000148/files/776_ruby_6020.zip
# /content/aozora/cards/000148/files/2372_ruby_2074.zip
# /content/aozora/cards/000148/files/784_ruby.zip
# /content/aozora/cards/000148/files/2675_ruby_6355.zip
# /content/aozora/cards/000148/files/2672_ruby_6337.zip
# /content/aozora/cards/000148/files/786_ruby_2375.zip
# /content/aozora/cards/000148/files/2375_ruby_2299.zip
# /content/aozora/cards/000148/files/795_txt.zip
# /content/aozora/cards/000148/files/42320_ruby_19559.zip
# /content/aozora/cards/000148/files/4689_txt_9473.zip
# /content/aozora/cards/000148/files/796_ruby_2452.zip
# /content/aozora/cards/000148/files/761_ruby_1861.zip
# /content/aozora/cards/000148/files/60818_ruby_74569.zip
# /content/aozora/cards/000148/files/771_ruby_2407.zip
# /content/aozora/cards/000148/files/55936_ruby_66914.zip
# /content/aozora/cards/000148/files/759_ruby.zip
# /content/aozora/cards/000148/files/765_ruby_2469.zip
# /content/aozora/cards/000148/files/1086_ruby_5742.zip
# /content/aozora/cards/000148/files/796_txt.zip
# /content/aozora/cards/000148/files/2575_ruby_3992.zip
# /content/aozora/cards/000148/files/1102_ruby_4488.zip
# /content/aozora/cards/000148/files/2383_ruby_2323.zip
# /content/aozora/cards/000148/files/2681_ruby_6323.zip
# /content/aozora/cards/000148/files/777_ruby.zip
# /content/aozora/cards/000148/files/777_txt.zip
# /content/aozora/cards/000148/files/792_ruby_2117.zip
# /content/aozora/cards/000148/files/756_ruby_2948.zip
# /content/aozora/cards/000148/files/798_txt.zip
# /content/aozora/cards/000148/files/777_ruby_1717.zip
# /content/aozora/cards/000148/files/2682_ruby_6333.zip
# /content/aozora/cards/000148/files/760_ruby_2341.zip
# /content/aozora/cards/000148/files/2673_ruby_6339.zip
# /content/aozora/cards/000148/files/758_txt.zip
# /content/aozora/cards/000148/files/752_ruby_2438.zip
# /content/aozora/cards/000148/files/2678_ruby.zip
# /content/aozora/cards/000148/files/772_ruby_33099.zip
# /content/aozora/cards/000148/files/4688_ruby_9465.zip
# /content/aozora/cards/000148/files/50420_ruby_76845.zip
# /content/aozora/cards/000148/files/754_ruby_2320.zip
# /content/aozora/cards/000148/files/785_ruby_1656.zip

# %%
# !ls /content/aozora/cards/000148/files/edit/789_ruby_5639*
# Out:
# /content/aozora/cards/000148/files/edit/789_ruby_5639_clns_utf-8.txt

# %%
df = pd.read_csv('/content/aozora/cards/000148/files/edit/789_ruby_5639_clns_utf-8.txt')
df
# Out:
#                                       text
# 0                                 吾輩は猫である。
# 1                                 名前はまだ無い。
# 2                        どこで生れたかとんと見当がつかぬ。
# 3     何でも薄暗いじめじめした所でニャーニャー泣いていた事だけは記憶している。
# 4                     吾輩はここで始めて人間というものを見た。
# ...                                    ...
# 9054                                吾輩は死ぬ。
# 9055                           死んでこの太平を得る。
# 9056                        太平は死ななければ得られぬ。
# 9057                         南無阿弥陀仏南無阿弥陀仏。
# 9058                           ありがたいありがたい。
#
# [9059 rows x 1 columns]

# %% [markdown]
# ## 参考
# - https://qiita.com/dzbt_dzbt/items/593dbd698a07c12a771c
# - https://itosae.com/github_sparsechekout/
# - https://qiita.com/bear_montblanc/items/64d7efd9e4ea7caa98f9
